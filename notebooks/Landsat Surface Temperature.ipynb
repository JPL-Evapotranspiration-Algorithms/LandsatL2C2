# %%
from LandsatL2C2 import LandsatL2C2
from sentinel_tiles import sentinel_tiles

# %%
landsat = LandsatL2C2()
# Out:
# [2025-09-26 10:49:47 INFO] Using earthaccess for Landsat data access (default)

# %%
geometry = sentinel_tiles.grid(tile="11SPS", cell_size=30)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
search_results = landsat.scene_search(start="2025-09-01", end="2025-09-26", target_geometry=geometry)
search_results
# Out:
# [2025-09-26 10:49:49 INFO] You're now authenticated with NASA Earthdata Login
# [2025-09-26 10:49:53 INFO] Searching dataset surface_reflectance from 2025-09-01 to 2025-09-26
# [2025-09-26 10:49:53 INFO] Granules found: 0
# [2025-09-26 10:49:53 INFO] Found 0 granules
# [2025-09-26 10:49:53 ERROR] EarthAccess scene search failed: No scenes found
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/Projects/LandsatL2C2/LandsatL2C2/LandsatL2C2.py:1437, in LandsatL2C2._scene_search_earthaccess(self, start, end, tiles, target_geometry, datasets, sensors, max_results, cloud_percent_min, cloud_percent_max, ascending)
#    1435 try:
#    1436     # Use the EarthAccess API for search
# -> 1437     scenes = self.earth_api.scene_search(
#    1438         start_date=start,
#    1439         end_date=end,
#    1440         target_geometry=target_geometry,
# ...
