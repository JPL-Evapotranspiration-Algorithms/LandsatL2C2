# %%
# Import the earthaccess library
import earthaccess

# Authenticate with earthaccess
# This will prompt the user to authenticate via Earthdata Login
auth = earthaccess.login()

# Search for available Landsat collections
collections = earthaccess.search_datasets(keyword="Landsat-9")

# Print the available collections
for collection in collections:
    print(collection["meta"]["native-id"], collection["meta"]["concept-id"])
    # print(collection["meta"].keys())
    # print(collection)  # Debugging: Print the entire collection object to inspect its structure

    # Adjust the keys based on the actual structure of the collection object
    # collection_id = collection.get('id', 'N/A')
    # collection_title = collection.get('title', 'N/A')
    # print(f"Collection ID: {collection_id}, Title: {collection_title}")
# Out:
# HLSL30V2 C2021957657-LPCLOUD
# mmt_collection_34928 C2746980408-LPCLOUD
# HLSL30_VI/2.0 C3246892554-LPCLOUD
# mmt_collection_25426 C2519119034-LPCLOUD
# MEaSUREs Greenland Quarterly Ice Sheet Velocity Mosaics from SAR and Landsat V005 C3297893512-NSIDC_CPRD
# MEaSUREs Greenland Monthly Ice Sheet Velocity Mosaics from SAR and Landsat V005 C3297904665-NSIDC_CPRD
# mmt_collection_25412 C2517904291-LPCLOUD
# High Mountain Asia Supraglacial Lake Extents on Debris Covered Glaciers, 1988-2023 V001 C3652561930-NSIDC_CPRD
# MEaSUREs Greenland Annual Ice Sheet Velocity Mosaics from SAR and Landsat V005 C3298042936-NSIDC_CPRD
# MEaSUREs ITS_LIVE Regional Glacier and Ice Sheet Surface Velocities V002 C3618748415-NSIDC_CPRD
# Select Northern Hemisphere Glacier Velocity Maps Using Customized autoRIFT and PlanetScope Imagery V001 C3508780105-NSIDC_ECS
# Select Northern Hemisphere Glacier Velocity Maps Using Customized autoRIFT and PlanetScope Imagery V001 C3649793958-NSIDC_CPRD
# ...
