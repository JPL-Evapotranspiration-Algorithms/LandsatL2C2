# %%
import earthaccess

# Authenticate with Earthdata
earthaccess.login(strategy="netrc")

# Verify surface reflectance concept ID
surface_reflectance = earthaccess.search_data(concept_id="C3442503899-USGS_EROS")
print(surface_reflectance)

# Verify surface temperature concept ID
surface_temperature = earthaccess.search_data(concept_id="C3442506077-USGS_EROS")
print(surface_temperature)

# Verify HLS Landsat short name
hls_landsat = earthaccess.search_data(short_name="HLSL30")
print(hls_landsat)
# Out:
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 print(surface_temperature)
#      14 # Verify HLS Landsat short name
# ---> 15 hls_landsat = earthaccess.search_data(short_name="HLSL30")
#      16 print(hls_landsat)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/LandsatL2C2/lib/python3.10/site-packages/earthaccess/api.py:142, in search_data(count, **kwargs)
#     140 if count > 0:
#     141     return query.get(count)
# --> 142 return query.get_all()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/LandsatL2C2/lib/python3.10/site-packages/cmr/queries.py:127, in Query.get_all(self)
#     118 def get_all(self) -> Sequence[Any]:
#     119     """
#     120     Returns all of the results for the query. This will call hits() first to determine how many
# ...
